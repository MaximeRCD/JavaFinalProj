# %% [markdown]
# ###

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\maxim\anaconda3\lib\site-packages (13.3.4)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\maxim\anaconda3\lib\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\maxim\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
# On précise que l'on veut des données française
fake = Faker("fr_FR")

# %%
# On veut créer de fausse date avec le bon format

# %%
import datetime
import random

# %% [markdown]
# ### Test datetime generator

# %%
fake.date_time_between(start_date=datetime.date(2020, 1,1), end_date=datetime.date(2022, 1,1)).strftime("%Y%m%d%H%M%S")
# Out:
# '20200819214631'

# %% [markdown]
# ### Test email generator

# %%
str.lower(f"{fake.first_name()}.{fake.last_name()}{random.randint(0,999)}@{fake.domain_name()}")
# Out:
# 'jérôme.gautier561@fischer.net'

# %% [markdown]
# ### Test ssn

# %%
fake.ssn()
# Out:
# '165056204199824'

# %% [markdown]
# ###  Test numero de téléphone

# %%
fake.phone_number()
# Out:
# '0586744831'

# %% [markdown]
# ### Test code maladie

# %%
code_maladie = {"A00–B99" : "Certaines maladies infectieuses et parasitaires",
"C00–D48" : "Tumeurs",
"D50–D89" : "Maladies du sang et des organes hématopoïétiques et certains troubles du système immunitaire",
"E00–E90" : "Maladies endocriniennes, nutritionnelles et métaboliques",
"F00–F99" : "Troubles mentaux et du comportement",
"G00–G99" : "Maladies du système nerveux",
"H00–H59" : "Maladies de l'œil et de ses annexes",
"H60–H95" : "Maladies de l'oreille et de l'apophyse mastoïde",
"I00–I99" : "Maladies de l'appareil circulatoire",
"J00–J99" : "Maladies de l'appareil respiratoire",
"K00–K93" : "Maladies de l'appareil digestif",
"L00–L99" : "Maladies de la peau et du tissu cellulaire sous-cutané",
"M00–M99" : "Maladies du système ostéo-articulaire, des muscles et du tissu conjonctif",
"N00–N99" : "Maladies de l'appareil génito-urinaire",
"O00–O99" : "Grossesse, accouchement et puerpéralité",
"P00–P96" : "Certaines affections dont l'origine se situe dans la période périnatale",
"Q00–Q99" : "Malformations congénitales et anomalies chromosomiques",
"R00–R99" : "Symptômes, signes et résultats anormaux d'examens cliniques et de laboratoire, non classés ailleurs",
"S00–T98" : "Lésions traumatiques, empoisonnements et certaines autres conséquences de causes externes",
"V01–Y98" : "Causes externes de morbidité et de mortalité",
"Z00–Z99" : "Facteurs influant sur l'état de santé et motifs de recours aux services de santé",
"U00–U99" : "Codes d'utilisation particulière"}

# %%
list(code_maladie.keys())[random.randint(0, len(code_maladie.keys())-1)]
# Out:
# 'E00–E90'

# %% [markdown]
# # Making good formatted fake Dataframe

# %%
import csv
import pandas as pd
from faker import Faker
import datetime
import random
from faker.providers import DynamicProvider

skill_provider = DynamicProvider(
     provider_name="skills",
     elements=["Python", "Pandas", "Linux", "SQL", "Data Mining"],
)


def fake_data_generation(records):
    fake = Faker('fr_FR')
    code_soin = [""]
    
    employee = []
    
    fake.add_provider(skill_provider)

    for i in range(records):
        first_name = fake.first_name()
        last_name = fake.last_name()



        employee.append({
                "ssn": fake.ssn(),
                "prenom": first_name,
                "nom": last_name,
                "date_naissance" : fake.date_of_birth(minimum_age=18, maximum_age=90).strftime("%Y-%m-%d"),
                "email": str.lower(f"{first_name}.{last_name}{random.randint(0,999)}@{fake.domain_name()}"),
                "numero_telephone" : fake.phone_number(),
                "id_remboursement" : random.randint(1000,9999),
                "code_soin" : list(code_maladie.keys())[random.randint(0, len(code_maladie.keys())-1)],
                "montant_remboursement" : random.randint(0,1000)/random.randint(10,20)
                })
        
    return employee


df = pd.DataFrame(fake_data_generation(10))

# %%
df
# Out:
#                ssn      prenom          nom date_naissance  \
# 0  106088313778124     Aurélie      Besnard     1970-03-04
# 1  244085935061604    Isabelle   Chevallier     1952-01-30
# 2  272075746336887     Colette      Monnier     1966-01-13
# 3  217105746399470  Christelle  Charpentier     1932-07-14
# 4  105076613614419   Françoise        Meyer     1936-12-20
# 5  284119550042289      Julien        Barre     1946-11-08
# 6  261088212118828    Patricia     Charrier     1971-03-12
# 7  147077055018539     Richard       Pineau     1998-06-29
# 8  100116806624047       Adèle      Gautier     1962-01-31
# 9  198095626048644     Tristan      Verdier     1990-04-12
#
#                                   email      numero_telephone  \
# 0         aurélie.besnard782@gimenez.fr     +33 1 81 09 43 33
# 1     isabelle.chevallier896@laporte.fr     +33 1 80 45 16 10
# 2         colette.monnier678@carlier.fr  +33 (0)8 07 05 26 89
# 3  christelle.charpentier714@renaud.com  +33 (0)5 45 65 42 41
# 4         françoise.meyer273@boutin.com            0182614421
# 5              julien.barre897@ramos.fr  +33 (0)1 56 12 45 31
# 6      patricia.charrier402@mercier.org     +33 3 22 52 02 64
# 7            richard.pineau770@laine.fr  +33 (0)7 14 05 63 11
# 8          adèle.gautier778@mercier.com            0466706606
# 9            tristan.verdier4@dupuy.com  +33 (0)5 94 10 30 39
#
#    id_remboursement code_soin  montant_remboursement
# 0              1810   M00–M99               0.529412
# 1              2057   H60–H95              47.900000
# 2              5399   M00–M99              98.500000
# 3              3932   A00–B99              19.300000
# 4              3571   H60–H95              26.615385
# 5              5191   A00–B99              66.200000
# 6              5552   I00–I99              61.000000
# 7              5703   H60–H95              30.705882
# 8              7747   Q00–Q99               9.916667
# 9              6251   H00–H59               2.250000

# %%
df.to_csv(f"./user{fake.date_time_between(start_date=datetime.date(2020, 1,1), end_date=datetime.date(2022, 1,1)).strftime('%Y%m%d%H%M%S')}.csv", index=False)

# %% [markdown]
# # Making bad formatted fake Dataframe

# %%
import datetime
import random
from faker.providers import DynamicProvider

skill_provider = DynamicProvider(
     provider_name="skills",
     elements=["Python", "Pandas", "Linux", "SQL", "Data Mining"],
)


def fake_data_generation(records):
    fake = Faker('fr_FR')
    currencies = ['£','€','$'] 
    employee = []
    
    fake.add_provider(skill_provider)

    for i in range(records):
        first_name = fake.first_name()
        last_name = fake.last_name()



        employee.append({
                "ssn": fake.ssn(),
                "prenom": first_name,
                "nom": last_name,
                "date_naissance" : fake.date_of_birth(minimum_age=18, maximum_age=90).strftime("%Y-%m-%d"),
                "email": str.lower(f"{first_name}.{last_name}{random.randint(0,999)}@{fake.domain_name()}"),
                "numero_telephone" : fake.phone_number(),
                "id_remboursement" : random.randint(1000,9999),
                "code_soin" : list(code_maladie.keys())[random.randint(0, len(code_maladie.keys())-1)],
                "montant_remboursement" : str(random.randint(0,1000)/random.randint(10,20)) + random.choice(currencies) ## Rajoute le symbol euros à la fin qui ne convient pas au type float attendu
                })
        
    return employee


df = pd.DataFrame(fake_data_generation(20))

# %%
df
# Out:
#                 ssn      prenom         nom date_naissance  \
# 0   120025746383603      Amélie     Lévêque     1981-04-28
# 1   293045212111555      Roland      Dumont     1987-03-16
# 2   216094604263897       Anaïs     Gimenez     1960-01-22
# 3   103087654038812   Guillaume      Gilles     1982-04-12
# 4   283111601552930     Corinne  Chevallier     1993-03-28
# 5   201076544032212    Zacharie     Michaud     1957-10-22
# 6   243021106909222     Michèle    Delaunay     1933-04-02
# 7   185050319095590        Jean    François     1941-05-19
# 8   293122123121644     Georges      Martin     1974-07-22
# 9   269012432209206      Sabine     Roussel     1980-03-03
# 10  246067055090776   Stéphanie     Guillou     1988-07-18
# 11  166036748251856       Anaïs     Delorme     2000-10-13
# 12  137049741143187        Éric      Durand     1989-11-27
# 13  198029402824989     Aurélie     Leblanc     1941-08-16
# 14  164106100198931    Adrienne      Martel     1975-06-13
# 15  219041927269148     Camille      Rocher     1952-10-28
# 16  190053018917820      Hugues        Jean     1960-01-27
# 17  236095439554247       Agnès       Peron     1947-07-08
# 18  217065313061309    Pénélope    Lefebvre     1980-11-02
# 19  157112123162674  Emmanuelle   Fernandez     1933-10-01
#
#                                  email      numero_telephone  \
# 0           amélie.lévêque712@alves.fr            0323521717
# 1          roland.dumont731@garcia.com  +33 (0)4 22 20 05 36
# 2             anaïs.gimenez77@roux.org        04 65 53 30 17
# 3    guillaume.gilles840@schneider.com     +33 1 30 83 47 97
# 4   corinne.chevallier354@delaunay.org        02 19 73 86 05
# 5        zacharie.michaud287@michel.fr     +33 4 49 36 44 24
# 6        michèle.delaunay327@julien.fr     +33 4 11 29 67 85
# 7            jean.françois898@riou.com            0176403420
# 8          georges.martin73@delorme.fr  +33 (0)1 42 76 60 13
# 9           sabine.roussel961@morel.fr        01 82 41 21 30
# 10         stéphanie.guillou883@da.com        03 51 14 88 84
# 11          anaïs.delorme589@vidal.com            0456479570
# 12          éric.durand960@laporte.com        02 85 47 61 80
# 13        aurélie.leblanc21@lenoir.net        02 41 62 98 09
# 14      adrienne.martel32@charrier.com     +33 5 57 48 14 91
# 15       camille.rocher116@tessier.com        01 40 39 71 69
# 16         hugues.jean429@chartier.com     +33 1 64 71 38 05
# 17          agnès.peron993@charles.com        01 43 93 21 57
# 18   pénélope.lefebvre624@gonzalez.org  +33 (0)2 33 51 67 45
# 19  emmanuelle.fernandez629@pascal.com        04 23 05 35 99
#
#     id_remboursement code_soin montant_remboursement
# 0               2863   H60–H95   32.833333333333336£
# 1               3319   Q00–Q99   32.333333333333336€
# 2               3345   F00–F99   23.235294117647058$
# 3               9484   A00–B99                 81.5£
# 4               5943   C00–D48                  8.5£
# 5               4422   V01–Y98   0.6363636363636364€
# 6               9941   E00–E90    71.54545454545455$
# 7               6405   O00–O99    4.333333333333333$
# 8               2150   J00–J99    5.823529411764706£
# 9               2686   O00–O99   28.733333333333334£
# 10              8916   S00–T98   31.666666666666668$
# 11              7898   Q00–Q99                78.25£
# 12              2912   N00–N99              43.8125€
# 13              3643   D50–D89    34.06666666666667£
# 14              5871   C00–D48                 12.8€
# 15              6793   F00–F99    87.54545454545455£
# 16              9989   R00–R99    45.88235294117647£
# 17              9629   H00–H59   30.363636363636363£
# 18              7818   Q00–Q99    61.18181818181818£
# 19              5909   R00–R99    43.15384615384615$

# %%
df.to_csv(f"./user{fake.date_time_between(start_date=datetime.date(2020, 1,1), end_date=datetime.date(2022, 1,1)).strftime('%Y%m%d%H%M%S')}.csv", index=False)
